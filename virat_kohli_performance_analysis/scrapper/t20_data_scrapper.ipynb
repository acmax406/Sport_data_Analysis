# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urlparse, parse_qs
import re
import pandas as pd
import numpy as np
 
webpage = requests.get('https://stats.espncricinfo.com/ci/engine/player/253802.html?class=3;template=results;type=allround;view=match')
sp = BeautifulSoup(webpage.content, 'html.parser')
# print(sp.text)

# %%
titles = sp.find_all(title='view the scorecard for this row')

def dataset(title):
    print(title)

    webpage2 = requests.get(title)
    sp2= BeautifulSoup(webpage2.content,'html.parser')
    
    table = sp2.findAll("table", { "class" : "ds-w-full ds-table ds-table-xs ds-table-fixed ci-scorecard-table" })
    
#     print(table[0].text)
#     print(table[1].text)
    
    player_name=[]
    out_by =[]
    runs=[]
    balls=[]
    empty=[]
    fours =[]
    sixes=[]
    strike=[]
    
    if len(table)>1:
        i = 0
        for row in table[0].findAll("tr"):
            if i%2 ==0:
                cells = row.findAll("td")
                temp = len(cells)
                if temp%8==0:
                    j=0
                    for cell in cells:
    #                     print(cell.text)
                        if j==0:
                            player_name.append(cell.text)
                            j=j+1
                        elif j==1:
                            out_by.append(cell.text)
                            j=j+1
                        elif j ==2:
                            runs.append(cell.text)
                            j=j+1
                        elif j ==3:
                            balls.append(cell.text)
                            j=j+1
                        elif j ==4:
                            empty.append(cell.text)
                            j=j+1
                        elif j ==5:
                            fours.append(cell.text)
                            j=j+1
                        elif j ==6:
                            sixes.append(cell.text)
                            j=j+1
                        else:
                            strike.append(cell.text)
                            j=j+1

            else:
                i =i+1

        k = 0
        for row in table[1].findAll("tr"):
            if k%2 ==0:
                cells = row.findAll("td")
                temp = len(cells)
                if temp%8==0:
                    m=0
                    for cell in cells:
    #                     print(cell.text)
                        if m==0:
                            player_name.append(cell.text)
                            m=m+1
                        elif m==1:
                            out_by.append(cell.text)
                            m=m+1
                        elif m ==2:
                            runs.append(cell.text)
                            m=m+1
                        elif m ==3:
                            balls.append(cell.text)
                            m=m+1
                        elif m ==4:
                            empty.append(cell.text)
                            m=m+1
                        elif m ==5:
                            fours.append(cell.text)
                            m=m+1
                        elif m ==6:
                            sixes.append(cell.text)
                            m=m+1
                        else:
                            strike.append(cell.text)
                            m=m+1

            else:
                k =k+1


        df = pd.DataFrame(player_name)
        df['out_by']=out_by
        df['runs']=runs
        df['balls']=balls
        df['empty']=empty
        df['fours']=fours
        df['sixes']=sixes
        df['strike_rate']=strike


        return df
    else:
        df2 = pd.DataFrame()
        return df2

# %%
for title in titles:
#     print(title.text)
    name= title.text
    title = title.get('href')
    
    title = 'https://stats.espncricinfo.com'+title
    
    test_data= dataset(title)
    
    test_data.to_csv(r't_20'+name+'.csv',index =False)
# Out:
# https://stats.espncricinfo.com/ci/engine/match/452153.html
# https://stats.espncricinfo.com/ci/engine/match/452154.html
# https://stats.espncricinfo.com/ci/engine/match/1119502.html
# https://stats.espncricinfo.com/ci/engine/match/1120093.html
# https://stats.espncricinfo.com/ci/engine/match/1120094.html
# https://stats.espncricinfo.com/ci/engine/match/1120095.html
# https://stats.espncricinfo.com/ci/engine/match/1122285.html
# https://stats.espncricinfo.com/ci/engine/match/1122286.html
# https://stats.espncricinfo.com/ci/engine/match/1140992.html
# https://stats.espncricinfo.com/ci/engine/match/1140993.html
# https://stats.espncricinfo.com/ci/engine/match/1119543.html
# https://stats.espncricinfo.com/ci/engine/match/1119544.html
# https://stats.espncricinfo.com/ci/engine/match/1119545.html
# https://stats.espncricinfo.com/ci/engine/match/1144990.html
# https://stats.espncricinfo.com/ci/engine/match/1144991.html
# https://stats.espncricinfo.com/ci/engine/match/1144992.html
# https://stats.espncricinfo.com/ci/engine/match/1168247.html
# https://stats.espncricinfo.com/ci/engine/match/1168248.html
# https://stats.espncricinfo.com/ci/engine/match/1188621.html
# https://stats.espncricinfo.com/ci/engine/match/1188622.html
# https://stats.espncricinfo.com/ci/engine/match/1188623.html
# https://stats.espncricinfo.com/ci/engine/match/1187005.html
# https://stats.espncricinfo.com/ci/engine/match/1187006.html
# https://stats.espncricinfo.com/ci/engine/match/1187018.html
# https://stats.espncricinfo.com/ci/engine/match/1187019.html
# https://stats.espncricinfo.com/ci/engine/match/1187020.html
# https://stats.espncricinfo.com/ci/engine/match/1202242.html
# https://stats.espncricinfo.com/ci/engine/match/1202243.html
# https://stats.espncricinfo.com/ci/engine/match/1202244.html
# https://stats.espncricinfo.com/ci/engine/match/1187677.html
# https://stats.espncricinfo.com/ci/engine/match/1187678.html
# https://stats.espncricinfo.com/ci/engine/match/1187679.html
# https://stats.espncricinfo.com/ci/engine/match/1187680.html
# https://stats.espncricinfo.com/ci/engine/match/1223952.html
# https://stats.espncricinfo.com/ci/engine/match/1223953.html
# https://stats.espncricinfo.com/ci/engine/match/1223954.html
# https://stats.espncricinfo.com/ci/engine/match/1243388.html
# https://stats.espncricinfo.com/ci/engine/match/1243389.html
# https://stats.espncricinfo.com/ci/engine/match/1243390.html
# https://stats.espncricinfo.com/ci/engine/match/1243391.html
# https://stats.espncricinfo.com/ci/engine/match/1243392.html
# https://stats.espncricinfo.com/ci/engine/match/1273727.html
# https://stats.espncricinfo.com/ci/engine/match/1273739.html
# https://stats.espncricinfo.com/ci/engine/match/1273744.html
# https://stats.espncricinfo.com/ci/engine/match/1273748.html
# https://stats.espncricinfo.com/ci/engine/match/1273753.html
# https://stats.espncricinfo.com/ci/engine/match/1278679.html
# https://stats.espncricinfo.com/ci/engine/match/1278680.html
# https://stats.espncricinfo.com/ci/engine/match/1276905.html
# https://stats.espncricinfo.com/ci/engine/match/1276906.html
